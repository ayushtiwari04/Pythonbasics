# %% [markdown]
# #OOPS

# %% [markdown]
# Q:1-  What is Object-Oriented Programming (OOP)?
#
# -: Object-Oriented Programming (OOP) is a programming paradigm that organizes software design around objects, rather than functions and logic. Objects are instances of classes, which are blueprints that define the structure and behavior (data and methods) of the objects.
#
# `CONCEPT OF OOPs`:-
#
# 1)class
# 2)object
# 3)encapsulation
# 4)inheritance
# 5)polymorphism
# 6)abstraction
#
#
#  Q:2  What is a class in OOP?
#
#  -: In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines the structure and behavior that the objects created from the class will have.
#
#  `A CLASS SPECIFIES`:
#
#  Attributes:→ represent the data or state of an object.
# Methods:→ represent the behavior or actions an object can perform.
#
# Q:3- What is an object in OOP?
#
# -: An Object is an instance of a class.
# A class is just a blueprint(like a design of a class)
# An object is the real things created from a blueprint of car (like actual car like BMW X60 or Audi A8)
#
# Q:4-  What is the difference between abstraction and encapsulation?
#
# -: ABSTRACTION:-Abstraction is hide the details.
#
# 1)Focus on what the object does, not how it does it.
# 2)Think of a car: You can drive, brake, steer — but you don't need to know how the engine work.
# 3)The user just calls accelerate().
#
# ENCAPSULATION:-Encapsulation is hide the data.
#
# 1)Keeps internal object state private and exposes it only through methods (getters/setters).
# 2)Think of a bank account: You can deposit/withdraw money through methods, but you can't directly access the balance variable.
# 3)User must use accelerate() and brake() to interact with it.
#
#  Q:5-What are dunder methods in Python?
#
#  -: Dunder method (short form of Double UNDERscore method) are special methods in python that start and end with double underscore.
#
# ex: init str , len ,name
#
# It is also called as magic method because python calls them automatically in certain situations.
#
# Q:6- Explain the concept of inheritance in OOP?
#
# -: Inheritance means one class (child class) can use the properties and methods of another class (parent class).
#
# `Types of Inheritance`:-
#
# 1)Single Inheritance → One child inherits from one parent.
# 2)Multiple Inheritance → One child inherits from multiple parents.
# 3)Multilevel Inheritance → A child inherits from a parent, and another child inherits from that child (grandchild).
# 4)Hierarchical Inheritance → Multiple children inherit from the same parent.
# 5)Hybrid Inheritance → Combination of different types.
#
#
#
#  Q:7-What is polymorphism in OOP?
#
# -: Polymorphism means many forms.
#
# It allows the same operation or function(methods) to behave differently depending on the object that is calling it.
# We can use the same function name, but it works differently for different objects.
#
# Key Benefits of Polymorphism:-
#
# 1)Code reusability:-same method names across classes.
# 2)Flexibility:-objects can be used interchangeably if they share a common interface.
# 3)Extensibility:-new classes can be added without modifying existing code.
#
#
#
# Q:8-How is encapsulation achieved in Python?
#
# -: It is a concept of hiding the internal details of an object and restricting direct access to some of its components.
#
# The developer only expose what is necessary through methods.
# It helps protect data from being changed accidentally.
# It is Achieved in Python by using Access Modifiers , Python uses naming conventions to indicate how “private” a variable or method
#
# Public : any one can access no underscore
#
# Protected : _(Single underscore)
#
# Private : __(double underscore)
#
#  Q:9-What is a constructor in Python?
#
#  -: A constructor is a special method in a class that is automatically called when an object of that class is created.
#
# Its main purpose is to initialize the object’s attributes (variables).
#
# The constructor method is always named: init()
#
#  Q:10-What are class and static methods in Python?
#
#  -: Class Method- The class method is a method that belongs to the class rather than an instance (object).
#
# It can access class variables, but not instance variables.
#
# It can be defined using the decorator @classmethod.
#
# first parameter is usually named cls (refers to the class).
#
# Static Method- A static method is a method that does not access the class or instance variables. -It’s like a regular function inside a class.
#
# Defined using the decorator @staticmethod
#
#  Q:11-What is method overloading in Python?
#
#  -: Python does not support method overloading by default. If you define multiple methods with the same name, only the latest definition will be used.
#
#  EXAMPLE:
#
#  def product(a, b):
#     p = a * b
#     print(p)
# def product(a, b, c):
#     p = a * b*c
#     print(p)
# product(4, 5, 5)
#
# The above example clarifies that Python doesn't support method overloading by default, however, it offers several techniques to simulate method overloading. In this article, we will explore different approaches of doing it.
#
# Using Variable Arguments (*args)
# Using Default Arguments
# Using Multiple Dispatch
#
# Overloading in Python is not supported in the traditional sense where multiple methods can have the same name but different parameters.
#
# Q:12- What is method overriding in OOP?
#
# -: When a subclass provides its own implementation of a method that is already defined in the parent class.
# The child class method overrides the parent's version.
# EXAMPLE:
# class Animal:
#     def sound(self):
#         print("Some sound")
#
# class Dog(Animal):
#     def sound(self):
#         print("Bark")
# d = Dog()
# d.sound()
#
# Q:13-What is a property decorator in Python?
#
# -: The @property decorator is used to turn a method into an attribute (read-only by default).
#
# It allows to access methods like attributes, without explicitly calling them with ().
#
# This is part of encapsulation, because it lets you control getter, setter, and deleter for class attributes
#
#  Q:14-Why is polymorphism important in OOP?
#
#  -: In OOP, it allows objects of different classes to be treated through a common interface, while each class can implement that interface in its own way.
#
#  Polymorphism is important because it provides:-
#
#  1)code reusability
#  2)flexibility and extensibility
#  3)simplified code
#  4)support abstraction
#  5)encourages loose coupling
#
#  Polymorphism is important because it makes OOP code flexible, reusable, extensible, and easier to maintain, which is the core strength of object-oriented design.
#
# Q:15-What is an abstract class in Python?
#
# -: An abstract class is a class that cannot be instantiated directly (you can’t create objects from it).
#
# It is used as a blueprint for other classes.
#
# Abstract classes can have abstract methods (methods declared but not implemented) that must be implemented by child classes.
#
# Q:16- What are the advantages of OOP?
#
# -: Advantages of OOP:-
#
# 1)Encapsulation:-Protects data from unwanted access.
#
# 2)Reusability:-Classes can be reused across projects.
#
# 3)Inheritance:-Enables code reuse and hierarchical design.
#
# 4)Polymorphism:-Objects can be used interchangeably, increasing flexibility.
#
# 5)Abstraction:-Hides complex implementation details.
#
# 6)Maintainability:-Easier to update and manage large projects.
#
#  Q:17-What is multiple inheritance in Python?
#
#  -: When a class is derived from more than one base class it is called multiple Inheritance. The derived class inherits all the features of the base case.
#
#  A class can inherit from more than one parent class:
#
#  EXAPLE:
#
#  class A:
#     def greet(self):
#         print("Hello from A")
# class B:
#     def greet(self):
#         print("Hello from B")
# class C(A, B):
#     pass
# c = C()
# c.greet()
#
# Python uses MRO (Method Resolution Order) to decide which parent's method to call.
#
# Q:18- What is the difference between a class variable and an instance variable?
#
# -: Multiple inheritance is a feature where a child class inherits from more than one parent class.
#
# The child class gets the properties and methods of all parent classes.
#
# Q:19- Explain the purpose of "__str__" and "__repr__" methods in Python?
#
# -: '__str__' Method:
#
# Returns a user-friendly string representation of an object.
# Called when you use print(object) or str(object).
#
# __repr__ Method:
#
#  Returns an unambiguous string representation of the object.
# Should ideally be a string that could be used to recreate the object.
# Called when you use repr(object) or just type the object in interactive mode.
#
# Q:20- What is the significance of the 'super()' function in Python?
#
# -: super() is a built-in function that allows a child class to access methods and attributes of its parent class.
#
# It is commonly used in inheritance to call the parent class constructor or methods without explicitly naming the parent.
#
# Q:21- What is the significance of the __del__ method in Python?
#
# -: Significance of __del__ method:-
#
# 1)Called when an object is about to be destroyed (garbage collected).
# 2)Rarely used; mainly for resource cleanup.
#
# EXAMPLE:
#
# class MyClass:
#     def __del__(self):
#         print("Object destroyed")
#
# Q:22-What is the difference between @staticmethod and @classmethod in Python?
#
# -: @staticmethod:
#
#  Cannot access instance (self) or class (cls) variables.
#
# @classmethod:
#
#  Can access class variables (cls) but not instance variables (self).
#
# Q:23- How does polymorphism work in Python with inheritance?
#
# -: Polymorphism means “many forms”.
#
# In OOP, it allows the same method or operator to behave differently depending on the object.
#
# Polymorphism + Inheritance:
#
# When a child class overrides a method from the parent class, the same method name behaves differently for different objects.
# This is called runtime polymorphism or dynamic polymorphism.
#
# Polymorphism allows the same interface to work with different objects.
# With inheritance, child classes can override parent methods → dynamic behavior at runtime.
#
# Q:24-What is method chaining in Python OOP?
#
# -: Method chaining is a technique where multiple methods are called in a single statement, one after another, on the same object.
#
# Each method returns the object itself (self), so the next method can be called immediately.
#
# It makes code more readable and concise.
#
#
# Q:25- What is the purpose of the __call__ method in Python?
#
# -: Purpose of __call__ method
#
# Allows an object to be called like a function:
#
# class Adder:
#
#     def __init__(self, n):
#         self.n = n
#     def __call__(self, x):
#         return self.n + x
# add5 = Adder(5)
# print(add5(10))

# %% [markdown]
# #PRACTICAL QUESTIONS

# %%
# Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal():
  def __init__(self,name):
    self.name = name

  def speak(self):
    print(f"The Name of Animal is: {self.name}")

class Dog(Animal):
  def speak(self):
    print(f"{self.name} Bark!")

a = Animal("MARCO")
a.speak()
d = Dog("JACK")
d.speak()
# Out:
# The Name of Animal is: MARCO
# JACK Bark!

# %%
# Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    def area(self):
        return math.pi * self.radius ** 2
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
circle = Circle(7)
rectangle = Rectangle(2, 8)
print(f"Area of circle: {circle.area():.2f}")
print(f"Area of rectangle: {rectangle.area()}")
# Out:
# Area of circle: 153.94
# Area of rectangle: 16

# %%
# Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute
class Vehicle:
  def __init__(self,type):
    self.type = type

class Car(Vehicle):
  def __init__(self,type,model):
    super().__init__(type)
    self.model = model

class ElectricCar(Car):
  def __init__(self,type,model,battery):
    super().__init__(type,model)
    self.battery = battery

e = ElectricCar("Xuv","MAHINDRA",5000)
print(e.type,e.model,e.battery)
# Out:
# Xuv MAHINDRA 5000

# %%
# Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
class Bird:
    def fly(self):
        print("Some birds can fly.")
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high.")
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly.")
for bird in [Sparrow(), Penguin()]:
    bird.fly()
# Out:
# Sparrow flies high.
# Penguins cannot fly.

# %%
# Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance
    def deposit(self, amount):
        self.__balance += amount
    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Insufficient balance.")
    def check_balance(self):
        return self.__balance

account = BankAccount(2000)
account.deposit(500)
account.withdraw(300)
print(account.check_balance())
# Out:
# 2200

# %%
# Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
class Instrument:
    def play(self):
        pass
class Guitar(Instrument):
    def play(self):
        print("Playing the guitar.")
class Piano(Instrument):
    def play(self):
        print("Playing the piano.")
for instr in [Guitar(), Piano()]:
    instr.play()
# Out:
# Playing the guitar.
# Playing the piano.

# %%
# Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a,b):
      return a-b
print(MathOperations.add_numbers(7, 3))
print(MathOperations.subtract_numbers(7, 3))
# Out:
# 10
# 4

# %%
# Implement a class Person with a class method to count the total number of persons created.
class Person:
    count = 0
    def __init__(self, name):
        self.name = name
        Person.count += 1
    @classmethod
    def total_persons(cls):
        return cls.count
p1 = Person("AYUSH")
p2 = Person("MANAS")
print(Person.total_persons())
# Out:
# 2

# %%
# Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"
f = Fraction(7, 4)
print(f)
# Out:
# 7/4

# %%
# Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

v1 = Vector(4, 2)
v2 = Vector(5, 6)

v3 = v1 + v2

print("v1 =", v1)
print("v2 =", v2)
print("v1 + v2 =", v3)
# Out:
# v1 = (4, 2)
# v2 = (5, 6)
# v1 + v2 = (9, 8)

# %%
# Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
p = Person("AYUSH", 21)
p.greet()
# Out:
# Hello, my name is AYUSH and I am 21 years old.

# %%
# Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades
    def average_grade(self):
        return sum(self.grades) / len(self.grades)
s = Student("Ayush", [80, 90, 70])
print(s.average_grade())
# Out:
# 80.0

# %%
# Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width
    def area(self):
        return self.length * self.width
r = Rectangle()
r.set_dimensions(6, 4)
print(r.area())
# Out:
# 24

# %%
# Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate
class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return super().calculate_salary(hours, rate) + bonus
m = Manager()
print(m.calculate_salary(40, 20, 100))
# Out:
# 900

# %%
# Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity
    def total_price(self):
        return self.price * self.quantity
p = Product("Laptop", 500, 3)
print(p.total_price())
# Out:
# 1500

# %%
# Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass
class Cow(Animal):
    def sound(self):
        print("Moo")
class Sheep(Animal):
    def sound(self):
        print("Baa")
for a in [Cow(), Sheep()]:
    a.sound()
# Out:
# Moo
# Baa

# %%
# Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"

b1 = Book("The Alchemist", "Paulo Coelho", 1988)
b2 = Book("Harry Potter", "J.K. Rowling", 1997)

print(b1.get_book_info())
print(b2.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988
# 'Harry Potter' by J.K. Rowling, published in 1997

# %%
#Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms
m = Mansion("123 Klm Street", 500000, 10)
print(m.address, m.price, m.number_of_rooms)
# Out:
# 123 Klm Street 500000 10
